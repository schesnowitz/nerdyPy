# %% [markdown]
# <a href="https://colab.research.google.com/github/schesnowitz/nerdyPy/blob/main/matlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import C.pyplot as plt


plt.plot(5, 10, "ro", label="Red Circle")
plt.plot(3, 6, "bp",  label="Blue Pentagon")
plt.legend()  # calls the lables
plt.show()

# %%
x = [0,1]
y = [0,5]
plt.plot(x, y, "r")
plt.plot([1, 2], [3, 4], "g")
plt.legend(['red line', 'green line'])
plt.show()

# %%
x = np.linspace(0,3*np.pi,123)
y = np.sin(x)


plt.plot(x, y, "k.")

plt.show()

# %%
x = np.linspace(3,3)
y = np.linspace(1,1)


plt.plot(x, y, "k.")

plt.show()
